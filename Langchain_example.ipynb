# %% [markdown]
# <a href="https://colab.research.google.com/github/agentsmithneo05/ai-examples/blob/main/Langchain_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('ashish')
# !pip install -q langchain-core langchain-groq python-dotenv
# Out:
# ashish
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 5.3 MB/s eta 0:00:00

# %%
import os
from google.colab import userdata
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage

# %%
# Fetch the key from Colab Secrets
os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')

# %%
# Initialize the model
llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.5
)

# %%
# Test a simple prompt
query = "Suggest three creative names for a new AI project."
response = llm.invoke(query)

print(response.content)
# Out:
# 1. **Lumina**: This name suggests light and understanding, which is fitting for an AI project that aims to illuminate new insights and knowledge.
# 2. **Nexa**: This name implies connection and nexus, which could represent the AI's ability to link different pieces of information, learn from data, and make new connections.
# 3. **Cerebro**: This name, which means "brain" in Spanish, implies a high level of intelligence and cognitive ability, making it a fitting choice for an AI project that aims to mimic human thought processes and learn from experience.
